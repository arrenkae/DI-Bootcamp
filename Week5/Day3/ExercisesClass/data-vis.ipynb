# %% [markdown]
# # DATA VISUALIZATION

# %%
import pandas as pd

# %%
# .plot

# %%
transactions = pd.read_csv('./transactions.csv')
transactions
# Out:
#              date  store_nbr  transactions
# 0      2013-01-01         25           770
# 1      2013-01-02          1          2111
# 2      2013-01-02          2          2358
# 3      2013-01-02          3          3487
# 4      2013-01-02          4          1922
# ...           ...        ...           ...
# 83483  2017-08-15         50          2804
# 83484  2017-08-15         51          1573
# 83485  2017-08-15         52          2255
# 83486  2017-08-15         53           932
# 83487  2017-08-15         54           802
#
# [83488 rows x 3 columns]

# %%
transactions.plot()
# Out:
# <Axes: >

# %%
trans_sm = transactions.head(10)
trans_sm.plot()
# Out:
# <Axes: >

# %%
trans_sm.set_index('date').plot()
# Out:
# <Axes: xlabel='date'>

# %%
trans_sm.plot(x='date', y='transactions');

# %% [markdown]
# # Assignment 1: Simple Line Chart
#
# Build a simple line plot for the oil series. Are there any interesting patterns here?
#
# What happened in 2014 to oil price?

# %%
oil = pd.read_csv('./oil.csv')
oil
# Out:
#             date  dcoilwtico
# 0     2013-01-01         NaN
# 1     2013-01-02       93.14
# 2     2013-01-03       92.97
# 3     2013-01-04       93.12
# 4     2013-01-07       93.20
# ...          ...         ...
# 1213  2017-08-25       47.65
# 1214  2017-08-28       46.40
# 1215  2017-08-29       46.46
# 1216  2017-08-30       45.96
# 1217  2017-08-31       47.26
#
# [1218 rows x 2 columns]

# %%
oil.plot(x='date');

# %%
(oil
.astype({'date':'datetime64[ns]'})
.set_index('date')
.loc['2013':'2014']
.plot())
# Out:
# <Axes: xlabel='date'>

# %%
oil.plot(
    x='date',
    title='oil transactions'
)
# Out:
# <Axes: title={'center': 'oil transactions'}, xlabel='date'>

# %%
trans_sm.plot(
    x='date',
    title='Transactions',
    ylabel='amount',
    color=['pink', 'red']
)
# Out:
# <Axes: title={'center': 'Transactions'}, xlabel='date', ylabel='amount'>

# %%
trans_sm.plot(
    x='date',
    title='Transactions',
    ylabel='amount',
    cmap='Pastel2'
)
# Out:
# <Axes: title={'center': 'Transactions'}, xlabel='date', ylabel='amount'>

# %%
trans_sm.plot(
    x='date',
    title='Transactions',
    ylabel='amount',
    cmap='Pastel2',
    style=['--','-.']
).legend(loc='center left')

# %%
trans_sm.plot(
    kind='bar',
    rot=45
)
# Out:
# <Axes: >

# %%
trans_sm.plot.pie(y='transactions')
# Out:
# <Axes: ylabel='transactions'>

# %%
trans_sm.plot.scatter(y='transactions',x='date')
# Out:
# <Axes: xlabel='date', ylabel='transactions'>
